# %%
#import function
from plot_bands import plot_bands

#Set variables
energy_range = [-2.5,5]
print_energies = True 
plot_name = 'test_plot.png' 
PROCAR_file = './VASP_files/PROCAR'
OUTCAR_file = './VASP_files/OUTCAR'

#run plot_bands function
plot_bands(PROCAR_file,OUTCAR_file,plot_name,energy_range = [-2.5,5], print_energies = True )
# Out:
# HOMO energy -4.62607968
# band_gap 1.7668436400000003
# spin flip gap 1.8330049500000003
# spin flip gap 2.46878134
# Final Energy -295.85703833
